# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
def total_loss():
    pass

# %%
import PIL.Image as img

cigar=img.open("apart.png")
cigar=cigar.convert("RGB")
cigar=cigar.resize((512,512))
plt.imshow(cigar)
cigar=np.reshape(cigar,[1,512,512,3])

# %%
model=keras.models.load_model('model124.h5',custom_objects={'total_loss':total_loss})
extractalemus = keras.Model(inputs=model.inputs,outputs=[layer.output for layer in model.layers])
features = extractalemus(cigar)
feat=features[1][0]

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(cigar[0])
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(feat[:,:,62])
plt.axis('off')
plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)

# %%
import math
fig=plt.figure(figsize=(16,16))
l=5
feat=features[l][0]
x= int(len(feat[0,0,])/8)
y= int(len(feat[0,0,])/x)
for i in range(len(feat[0,0,])):
    ax=plt.subplot(x,y,i+1)
    plt.imshow(feat[:,:,i])
    plt.axis('off')

plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)

# %%
filters=[]
for i in range(len(features)):
    filters.append(len(features[i][0][0][0]))

# %%
model.layers[0].input
# Out:
# <KerasTensor: shape=(None, 512, 512, 3) dtype=float32 (created by layer 'input_1')>
